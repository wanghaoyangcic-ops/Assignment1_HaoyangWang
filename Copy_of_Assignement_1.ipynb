# %% [markdown]
# # CISC 121 – Assignment-1
# Name: HaoyangWang
#
# Student ID: 20425153
#
# Section: 001
#
# Date: 20/9/2025
#
# Github Link of this notebook (the link of Github Repo where you saved your notebook)

# %% [markdown]
# #  Problem 1

# %% [markdown]
# ## 1. Understanding & Breakdown
# **Understand the problem**: Generate a string 0using integer in a loop and some simple math instructions(comperesion, division....)
#
# **Input**: 1 <= n <= 10^4 (given an integer and its range)
#
# **Output**:
# * The result supposed to be 1 indexed
# * The strings "FizzBuzz" "Fizz" "Buzz"
#
# **Constraints**:
# 1. The input integer n can be very large (like 10000), becarefor with the loop.
# 2. Reminding users
#
# **My plan**:
# 1.   Defer a function
# 2.   Create an empty dictionary
# 3.   If i can be devided by 3 and 5, then we have "FizzBuzz"
# 4.   If i is only divided by 3, then we get "Fizz"
# 5.   If i is only divided by 5 , then we get "Buzz"
# 6.   else, append the string

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# I reviewed the third solution under the LeetCode “Solutions” tab:
# https://leetcode.com/problems/fizz-buzz/solutions/7195167/easy-beginner-friendly-solution/
# I learned the usage of the command "Class," which I hadn't known before; but in fact, the author's idea was exactly the same as mine.

# %%
# My draft code
def fizzBuzz(n):
    dic = []
    for i in range(1, n+1):
        if i % 3 == 0:
            dic.append("Fizz")
        elif i % 5 == 0:
            dic.append("Buzz")
        elif i % 3 == 0 and i % 5 == 0:
            dic.append("FizzBuzz")
        else:
            dic.append(str(i))
    return dic

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final working solution
def fizzBuzz(n):
    dic = []
    for i in range(1, n+1):
        if i % 3 == 0 and i % 5 == 0:
            dic.append("FizzBuzz")
        elif i % 3 == 0:
            dic.append("Fizz")
        elif i % 5 == 0:
            dic.append("Buzz")
        else:
            dic.append(str(i))
    return dic

# test
print(fizzBuzz(3))   # ["1","2","Fizz"]
print(fizzBuzz(5))   # ["1","2","Fizz","4","Buzz"]
print(fizzBuzz(15))  # ["1","2","Fizz","4","Buzz","Fizz","7","8","Fizz","Buzz","11","Fizz","13","14","FizzBuzz"]

#AI Disclaimer: I used DeepSeek to optimize [how to run code more efficiently]
#AI Disclaimer: I put half part of the code into ChatGPT to check for errors after finding that the code couldn't return the correct results

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: The incorrect use of if and elif
# Draft version:(Logial error)
if i % 3 == 0:
    dic.append("Fizz")
elif i % 5 == 0:


# Fixed version:
if i % 3 == 0 and i % 5 == 0:
    dic.append("FizzBuzz")
elif i % 3 == 0:

# %%
# Fix 2: Added testing code
# Draft version: (None)

#Fiexed Version:(Visable and Cleaner, given 3 examples)
# test
print(fizzBuzz(3))  # ["1","2","Fizz"]
print(fizzBuzz(5))  # ["1","2","Fizz","4","Buzz"]
print(fizzBuzz(15)) # ["1","2","Fizz","4","Buzz","Fizz","7","8","Fizz","Buzz","11","Fizz","13","14","FizzBuzz"]

# %% [markdown]
# ## 5. Reflection on Your Contribution
# 1. I used ChatGPT (Level 4) to review my code and found an error: the logical relationship between if and elif was incorrect. Additionally, placing “and” at the end of the code would cause the order of the output string to be reversed.
# 2. I asked ChatGPT (Level 1) whether an empty dictionary can be named "dic", and it told me that while it is not incorrect, it would be better to rename the dictionary to something related to the problem for easier understanding. However, I ultimately did not adopt this suggestion.

# %% [markdown]
# #  Problem 2

# %% [markdown]
# ## 1. Understanding & Breakdown
# **Understand the problem**:
#
# In my opinion, the problem requires a judgment type of task, and it is expected to involve comparison operations and a simple for loop.
#
# **Input**:
#
# x ( has a range needs to be figure out)
#
# **Output**:
#
# True or False
#
#
# **Constraints**:
#
# *   What if the number is negative?
# *   What if the number is a decimal? And what about fractions?
#
# **My plan**:
#
#
# 1.   Retrun False directly if x < 0(negative)
# 2.   Reverse the result then compare

# %% [markdown]
# ## 2. Peer Review & Draft Code
# I reviewed the solution under the LeetCode “Solutions” tab
# https://leetcode.com/problems/palindrome-number/solutions/7140402/clean-simple-solution-one-liner-optimized-code-easy-explanation/
#
# What a brilliant idea! He used the method of reversing a string instead of blindly comparing values, which allowed the code to be completed in just three lines. However, this requires a strong command of Python instructions.

# %%
#My Draft:
def Fun_palindrome(y, x):
   return str(x) == (str(x))[::-1]
# test
print(Fun_palindrome(121))   # True

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final working solution
def Fun_palindrome(x):
    if x < 0:
        return False
    return str(x) == str(x)[::-1]

# test
print(Fun_palindrome(121))   # True
print(Fun_palindrome(-121))  # False
print(Fun_palindrome(10))    # False

#AI Disclaimer: I used ChatGPT to modify my function, making my code run smoothly.

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: The incorrect use of parameters(only 1 parameter needed!!)
# Draft version:(parameter error)
def Fun_palindrome(y, x):

#Fixed version
def Fun_palindrome(x):

# %%
# Fix 2: Did not test negative numbers
# Draft Version:
# test
print(Fun_palindrome(121))   # True


# Fixed version:(add more situations):
# test
print(Fun_palindrome(121))   # True
print(Fun_palindrome(-121))  # False
print(Fun_palindrome(10))    # False

# %% [markdown]
# ## 5. Reflection on Your Contribution
# I used ChatGPT (Level 3) to correct a logical error because my reference material was incorrect. Its idea was ingenious, but it did not read the problem carefully—the number of parameters was wrong.

# %% [markdown]
# #  Problem 3

# %% [markdown]
# ## 1. Understanding & Breakdown
# **Understand the problem**:
#
# The problem requires writing a program to reverse very large numbers. I think I can start by working with smaller numbers.
#
# **Input**:
#
# a 32-bit integer x
#
# **Output**:
#
# The reversed integer of x.
#
# **Constraints**:
# * Check both positive and negative cases
# * The given extreme values may be too large
#
# **My plan**:
# 1. Determine whether x is negative and find its absolute value (regardless of sign)
#
# 2. Extract the last digit of x and append it to the end of a variable
#
# 3. Remove the last digit of x until x becomes 0
#
# 4. Check if the result exceeds the 32-bit range. If it does, return 0; otherwise, return the reversed value

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# I reviewed the solution under the LeetCode “Solutions” tab:
# https://leetcode.com/problems/reverse-integer/solutions/3099545/my-c-solution-beats-100-0ms-run-time/
#
# I cannot guarantee the correctness of this solution—even the top-ranked answer doesn't seem to be widely accepted. However, it gave me an idea: I can start with a `while` loop and write longer code to avoid logical errors.

# %%
# My Draft Code:
def reverse(x):
  num_min = -2**31 #given the range
  num_max = 2**31-1
if x < 0:
  sign = -1
if x > 0:
  sign = 1
  # Cant not really sovle it.
  # I did not use AI for this part

# %% [markdown]
# ## 3. Final Correct Code

# %%
def reverse(x):
    INT_MIN = -2**31
    INT_MAX = 2**31 - 1
    if x < 0:
        sign = -1
        x = -x
    else:
        sign = 1
    rev = 0
    while x > 0:
        digit = x % 10
        rev = rev * 10 + digit
        x = x // 10
    rev = rev * sign
    if rev < INT_MIN or rev > INT_MAX:
        return 0
    else:
        return rev

print(reverse(123))     # 321
print(reverse(-123))    # -321
print(reverse(120))     # 21
print(reverse(1534236469))  # 0

#AI:I used ChatGPT (Level 4) in the latter part and asked it to continue writing based on my initial approach.

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
#Fix 1 : I completed the latter part of the code with the help of AI.
#Draft:
# Cant not really sovle it.

#Fixed:
rev = 0
    while x > 0:
        digit = x % 10
        rev = rev * 10 + digit
        x = x // 10
    rev = rev * sign
    if rev < INT_MIN or rev > INT_MAX:
        return 0
    else:
        return rev
        #Still confused = =

# %%
#Fix 1 : I added some tests:
#Fixed version:
print(reverse(123))     # 321
print(reverse(-123))    # -321
print(reverse(120))     # 21
print(reverse(1534236469))  # 0

# %% [markdown]
# ## 5. Reflection on Your Contribution
# 1. I overused AI in this part to complete my code. I had my own ideas but cant writ it down

# %% [markdown]
# #  Problem 4

# %% [markdown]
# ## 1. Understanding & Breakdown
# **Understand the problem**:
#
# The return value of adding an integer and an integer array is greater than the integer. I think I will use an array, check each unit, and see if they have appeared before.
#
# **Input**:
#
# *   nums(2<=n<=10^4)
# *   target(the result after added)
#
# **Output**:
# * two index satisfied the sum of them == traget
#
# **Constraints**:
# *   Elements can't be repeated
# *   Only one result
#
# **My plan**:
# 1. Check each number in the array.
# 2. Calculate the difference.
# 3. Check if this number has already appeared in the previous numbers.
# 4. If it appears, return its index and the current index.
#
# 5. If it does not appear, store the current number and its index, then continue the loop.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# I reviewed the top solution under the LeetCode “Solutions” tab:
# https://leetcode.com/problems/two-sum/solutions/127810/two-sum/
# I'm confidence with this problem, and I just checked the test results.

# %%
#Draft code:
def twoSum(nums, target):
    for i in range(len(nums)):
        for j in range(i+1, len(nums)):
            if nums[i] + nums[j] == target:
                return [i, j]
#AI; I searched on Google to see if there are any points to note regarding the two parameters.

# %% [markdown]
# ## 3. Final Correct Code

# %%
#Final Code:
def twoSum(nums, target):
    seen = {}
    for i, num in enumerate(nums):
        complement = target - num
        if complement in seen:
            return [seen[complement], i]
        seen[num] = i

# test
print(twoSum([2,7,11,15], 9))   # [0,1]
print(twoSum([3,2,4], 6))     # [1,2]
print(twoSum([3,3], 6))      # [0,1]


#Or
from typing import List
class Solution:
    def Two_Sum(self, nums: List[int], target: int) -> List[int]:
        for i in range(len(nums)):
            for j in range(i + 1, len(nums)):
                if nums[j] == target - nums[i]:
                    return [i, j]
        return []
#AI: I used ChatGPT (Level 4) to improve the coherence of the code, and it told me that my draft version was inefficient.
#AI I used ChatGPT(lever 4) to learn how to use List in python.
# Out:
# [0, 1]
# [1, 2]
# [0, 1]

# %% [markdown]
# ## 4. Review & Fixes

# %%
#Fix: In fact, my draft code did not contain errors that needed to be modified, but it was inefficient. Even though I revised the final version, my code remains equally functional.
#Draft code:(wrong parameters)
def twoSum(nums, target):
    for i in range(len(nums)):

#Fixed version:
from typing import List
class Solution:
    def Two_Sum(self, nums: List[int], target: int) -> List[int]:
# Out:
#   File "/tmp/ipython-input-786614615.py", line 7
#     from typing import List
#                            ^
# IndentationError: expected an indented block after 'for' statement on line 4

# %% [markdown]
# ## 5. Reflection on Your Contribution
# 1. After watching the demonstration on LeetCode, I didn't understand how to use Lists, but the AI taught me how to use them.
# 2. My method is rather brute-force. The AI pointed out that while it is not incorrect, it is unreasonable and difficult to apply.

# %% [markdown]
# #  Problem 5

# %% [markdown]
# ## 1. Understanding & Breakdown
# **Understand the problem**:
#
# **Input**:
#
# String S
#
# **Output**:
#
# True or False
#
# **Constraints**:
# s consists only of printable ASCII characters.
#
# **My plan**:
#
# 1. Remove all characters from the string and convert it to lowercase.
# 2. Obtain a processed string.
# 3. Check if it is equal to its reverse.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# I reviewed the top solution under the LeetCode “Solutions” tab:
# https://leetcode.com/problems/valid-palindrome/solutions/546199/valid-palindrome/
# I didn't like their answers, so I went to Github.
# https://gist.github.com/Prosen-Ghosh/74aff5fac59d5cc5f30995caf07e517a
# They used commands that I haven't learned, which helped me further understand Python.

# %%
#Draft

def isPalindrome(s):
    s = s.lower()
    new_s = ""
    for ch in s:
        if ch.isalnum():
            new_s = new_s + ch
    if new_s == new_s[::-1]:
        return True
    else:
        return False

# %% [markdown]
# ## 3. Final Correct Code

# %%
#Final version
def isPalindrome(s):
    s = s.lower()
    new_s = ""
    for ch in s:
        if ch.isalnum():
            new_s = new_s + ch
    return new_s == new_s[::-1]
    #AI: I asked ChatGPT to remind me how to use the reverse function.
    #AI: Fix problems(return errors)

# %% [markdown]
# ## 4. Review & Fixes

# %%
#Fix 1: The defer function shows an error and prompts that there is a space,deleted it.
#Draft:

def isPalindrome(s):
    s = s.lower()

#Fixed:

def isPalindrome(s):
    s = s.lower()

# %%
#Fix2: It should not return a boolean value.(true or false)
#Draft(shows boolean value):
if new_s == new_s[::-1]:
        return True
    else:
        return False

#Fixed:
   if ch.isalnum():
            new_s = new_s + ch
    return new_s == new_s[::-1]

# %% [markdown]
# ## 5. Reflection on Your Contribution
# If you directly return the comparison result, you won't need if/else or explicitly return a boolean value.

# %% [markdown]
# #  Repeat this template for Problems 2–5
# You may copy-paste the above section 4 more times or duplicate cells in your notebook environment.
#
# Remember:
# Proper attribution
# No copy-pasting from AI or others

# %% [markdown]
# 1. Your Name:HaoyangWang
# 2. Section:001
# 3. ID:20425153
# 4. Github Link of this notebook (the link of Github Repo where you saved your notebook)
# 5. Chat (Saved Chat  with your AI tool in a shared Document link)[Optional]

# %% [markdown]
# # **The most important part of writing code is not the code itself, but the thinking that leads to it. Thank You**
